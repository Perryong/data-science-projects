# %% [markdown]
# # Data Preprocessing
#
# This notebook demonstrates data preprocessing and feature engineering steps.

# %%
import sys
from pathlib import Path

sys.path.insert(0, str(Path.cwd().parent / "src"))

from food_delivery_analysis import (
    DataLoader,
    DataPreprocessor,
    setup_logger
)
import pandas as pd
