# %% [markdown]
# # Data Loading and Initial Exploration
#
# This notebook demonstrates how to load and initially explore the food delivery dataset.

# %%
import sys
from pathlib import Path

# Add src to path
sys.path.insert(0, str(Path.cwd().parent / "src"))

from food_delivery_analysis import DataLoader, setup_logger
import pandas as pd
import numpy as np

# %%
# Setup logging
logger = setup_logger()

# %%
# Initialize data loader
loader = DataLoader()

# Load data
data_path = Path("../data/raw/Food_Delivery_Route_Efficiency_Dataset.csv")
df = loader.load_csv(data_path)

print(f"Data shape: {df.shape}")
df.head()

# %%
# Get data information
info = loader.get_data_info()
print("Dataset Information:")
print(f"Shape: {info['shape']}")
print(f"Columns: {info['columns']}")
print(f"Memory Usage: {info['memory_usage_mb']:.2f} MB")
